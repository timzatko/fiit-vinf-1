# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('out.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57521 entries, 0 to 57520
# Data columns (total 23 columns):
# url                    57521 non-null object
# itemName               57521 non-null object
# currentPrice           53928 non-null object
# oldPrice               26004 non-null object
# description            40987 non-null object
# averageRating          13770 non-null object
# author                 55464 non-null object
# editorialReviews       9529 non-null object
# format                 15261 non-null object
# category               57521 non-null object
# release_date           18110 non-null object
# isbn-13                30481 non-null object
# publisher              39355 non-null object
# publication_date       39391 non-null object
# series                 13612 non-null object
# pages                  28644 non-null object
# sales_rank             26804 non-null object
# product_dimensions     23788 non-null object
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.barnesandnoble.com/w/nows-the-time...
# 1  https://www.barnesandnoble.com/w/on-becoming-c...
# 2  https://www.barnesandnoble.com/w/fledgling-han...
# 3  https://www.barnesandnoble.com/w/best-silverto...
# 4  https://www.barnesandnoble.com/w/quote-acrosti...
#
#                                             itemName currentPrice oldPrice  \
# 0                                     Now's the Time          NaN      NaN
# 1  On Becoming Childwise: Parenting Your Child fr...       $15.11   $15.95
# 2                         The Fledgling Handbook 101       $15.29   $16.99
# 3                             Best: Silvertone Years       $37.04   $38.99
# 4  Quote Acrostic Favorites: Features 50 Rewardin...        $9.95      NaN
#
#                                          description averageRating  \
# 0                                                NaN           NaN
# ...
