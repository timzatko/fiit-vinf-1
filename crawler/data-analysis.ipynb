# %% [markdown]
# # Data Analysis - check correctness of the data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('out.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110270 entries, 0 to 110269
# Data columns (total 25 columns):
# id                     110270 non-null object
# url                    110270 non-null object
# itemName               110270 non-null object
# currentPrice           104667 non-null object
# oldPrice               33116 non-null object
# description            87661 non-null object
# averageRating          18286 non-null object
# author                 108367 non-null object
# editorialReviews       15603 non-null object
# format                 31773 non-null object
# category               110149 non-null object
# image                  110270 non-null object
# release_date           13311 non-null object
# isbn-13                80500 non-null object
# publisher              96665 non-null object
# publication_date       96764 non-null object
# series                 26881 non-null object
# pages                  73111 non-null object
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.barnesandnoble.com/w/nows-the-time...
# 1  https://www.barnesandnoble.com/w/on-becoming-c...
# 2  https://www.barnesandnoble.com/w/fledgling-han...
# 3  https://www.barnesandnoble.com/w/best-silverto...
# 4  https://www.barnesandnoble.com/w/quote-acrosti...
#
#                                             itemName currentPrice oldPrice  \
# 0                                     Now's the Time          NaN      NaN
# 1  On Becoming Childwise: Parenting Your Child fr...       $15.11   $15.95
# 2                         The Fledgling Handbook 101       $15.29   $16.99
# 3                             Best: Silvertone Years       $37.04   $38.99
# 4  Quote Acrostic Favorites: Features 50 Rewardin...        $9.95      NaN
#
#                                          description averageRating  \
# 0                                                NaN           NaN
# ...

# %% [markdown]
# ## category

# %%
df['category'].value_counts()
# Out:
# Books                  33445
# Music                  18046
# Kids' Books             2990
# Textbooks               1710
# Teen Books               871
# NOOK Books               330
# category                  33
# Movies & TV               33
# Newsstand                 30
# Gift, Home & Office       13
# Toys                       9
# 128145                     4
# 129658                     2
# 123419                     2
# NOOK                       2
# 11361                      1
# Name: category, dtype: int64

# %%
df['category'].unique()
# Out:
# array(['Music', 'Books', 'Teen Books', 'Textbooks', "Kids' Books",
#        'category', 'Newsstand', 'NOOK Books', 'Gift, Home & Office',
#        'Toys', '128145', '129658', 'Movies & TV', '123419', '11361',
#        'NOOK'], dtype=object)

# %% [markdown]
# ## age_range

# %%
df['age_range'].value_counts()
# Out:
# 18  Years               2432
# 8 - 12 Years             418
# 4 - 8 Years              310
# 13 - 17 Years            210
# 12  Years                188
# 9 - 12 Years             175
# 13 - 18 Years            161
# 12 - 17 Years            159
# 14 - 17 Years            131
# 7 - 10 Years             128
# 5 - 8 Years              128
# 3 - 5 Years              128
# 16  Years                118
# 13  Years                111
# 3 - 7 Years               97
# 6 - 8 Years               94
# 4 - 7 Years               90
# 2 - 5 Years               82
# 16 - 18 Years             79
# 14 - 18 Years             77
# 6 - 9 Years               73
# 10 - 14 Years             72
# 5 - 11 Years              62
# 3 Months to 18 Years      62
# 3 Months to 3 Years       53
# 8 - 11 Years              49
# 5 - 7 Years               48
# 3 - 6 Years               48
# 12 - 18 Years             45
# 4 - 6 Years               43
#                         ...
# 9 - 15 Years               1
# ...

# %%
df['upc'].value_counts()
# Out:
# 0886978119728    14
# 0016728309028    13
# 0099402612928    13
# 0610017442122    13
# 0888751578029    13
# 5036436112821    13
# 0663993150826    13
# 0015891384528    13
# 5411867114406    13
# 5060113445025    13
# 0686647022003    13
# 0886976605728    13
# 0813543021780    13
# 0016728138727    13
# 0099402570921    13
# 0696532005325    13
# 0686647026100    13
# 0808720012026    13
# 0718795604128    13
# 0730003732829    13
# 0686647025707    13
# 5019317020545    13
# 0748871500327    13
# 0663993101620    13
# 5411867114550    13
# 0016728138826    13
# 0888751735927    13
# 0751937390220    13
# 0016728136228    13
# 0640864269047    13
#                  ..
# 0888295365277     1
# 5019317070168     1
# 0190296920189     1
# 0701122117521     1
# 0787991103124     1
# 0744430685115     1
# 0747313161768     1
# 0610583536829     1
# 4046661353822     1
# 5052571050729     1
# 5099924843324     1
# 0093624831624     1
# 0027297880221     1
# 0802644901527     1
# ...

# %%
df[df['sales_rank'].isna()]
# Out:
#                                       id  \
# 2       21cfcf359d2f6aee76b0a0b60b07bee6
# 6       cd3e8e076493bfea3df40f427f33a3e3
# 9       369506b8c0e3a5d50d65c029f6f5808c
# 11      1d2423d569fd50cb9842abfed7970b4e
# 12      45e0c72c1a536a2f36241e05101234f5
# 13      9f95c78a747a267ee60bb8f1b54edf4e
# 16      59c58cc7ff7eab5f5b49bfe41bdd44ca
# 18      c8e81e092e9c63fe3bcfddec31e6a4bc
# 20      bb9ab519ee9048161eeb85114f278f70
# 21      5d70567b58db0a470c9582bd9cbc3551
# 24      7e4f397544e21d1dc0eb2ed1beeed690
# 25      0412f8fa4b3b463c89d6a5e8117d1a98
# 27      15bf8386af01d267f422c9f5661675ae
# 28      a70137585242a7967308e06b2e63bd38
# 31      b73ffb72b8998e98dbe9430c20908ec7
# 36      8bfa9c50fe1790764b2d64ca6a98d82d
# 37      f5b0b795290131d4dac2d9e5cad17c5f
# 38      4b4584c16a7888a4c8cf1b4c19572044
# 39      2fd82b6d141d81600dcb91734335e120
# 40      2f8c6783fa13d584733ccd66a848f49b
# 41      e1c02baa9ec05fd33749680d569b7213
# 45      486ba799199cdc9b3561e6e44ace68d7
# ...
